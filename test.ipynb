# %%
conn.close()

# %%
import sqlite3

# 连接到 SQLite3 数据库
db_path = 'chroma_langchain_db\chroma.sqlite3'  # 替换为你的数据库文件路径
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# 获取数据库中所有的表名
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# 遍历所有表
for table in tables:
    table_name = table[0]
    print(f"表名: {table_name}")
    
    # 获取每个表的字段信息
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    
    print(f"字段: {columns}")
    for column in columns:
        column_name = column[1]
        column_type = column[2]
        print(f"字段名: {column_name}, 数据类型: {column_type}")
    print('-' * 40)

# 关闭连接
conn.close()
# Out:
# 表名: migrations
# 字段: [(0, 'dir', 'TEXT', 1, None, 1), (1, 'version', 'INTEGER', 1, None, 2), (2, 'filename', 'TEXT', 1, None, 0), (3, 'sql', 'TEXT', 1, None, 0), (4, 'hash', 'TEXT', 1, None, 0)]
# 字段名: dir, 数据类型: TEXT
# 字段名: version, 数据类型: INTEGER
# 字段名: filename, 数据类型: TEXT
# 字段名: sql, 数据类型: TEXT
# 字段名: hash, 数据类型: TEXT
# ----------------------------------------
# 表名: acquire_write
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'lock_status', 'INTEGER', 1, None, 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: lock_status, 数据类型: INTEGER
# ----------------------------------------
# 表名: collection_metadata
# 字段: [(0, 'collection_id', 'TEXT', 0, None, 1), (1, 'key', 'TEXT', 1, None, 2), (2, 'str_value', 'TEXT', 0, None, 0), (3, 'int_value', 'INTEGER', 0, None, 0), (4, 'float_value', 'REAL', 0, None, 0), (5, 'bool_value', 'INTEGER', 0, None, 0)]
# 字段名: collection_id, 数据类型: TEXT
# 字段名: key, 数据类型: TEXT
# 字段名: str_value, 数据类型: TEXT
# 字段名: int_value, 数据类型: INTEGER
# 字段名: float_value, 数据类型: REAL
# 字段名: bool_value, 数据类型: INTEGER
# ----------------------------------------
# 表名: segment_metadata
# 字段: [(0, 'segment_id', 'TEXT', 0, None, 1), (1, 'key', 'TEXT', 1, None, 2), (2, 'str_value', 'TEXT', 0, None, 0), (3, 'int_value', 'INTEGER', 0, None, 0), (4, 'float_value', 'REAL', 0, None, 0), (5, 'bool_value', 'INTEGER', 0, None, 0)]
# 字段名: segment_id, 数据类型: TEXT
# 字段名: key, 数据类型: TEXT
# 字段名: str_value, 数据类型: TEXT
# 字段名: int_value, 数据类型: INTEGER
# 字段名: float_value, 数据类型: REAL
# 字段名: bool_value, 数据类型: INTEGER
# ----------------------------------------
# 表名: tenants
# 字段: [(0, 'id', 'TEXT', 0, None, 1)]
# 字段名: id, 数据类型: TEXT
# ----------------------------------------
# 表名: databases
# 字段: [(0, 'id', 'TEXT', 0, None, 1), (1, 'name', 'TEXT', 1, None, 0), (2, 'tenant_id', 'TEXT', 1, None, 0)]
# 字段名: id, 数据类型: TEXT
# 字段名: name, 数据类型: TEXT
# 字段名: tenant_id, 数据类型: TEXT
# ----------------------------------------
# 表名: collections
# 字段: [(0, 'id', 'TEXT', 0, None, 1), (1, 'name', 'TEXT', 1, None, 0), (2, 'dimension', 'INTEGER', 0, None, 0), (3, 'database_id', 'TEXT', 1, None, 0), (4, 'config_json_str', 'TEXT', 0, None, 0), (5, 'schema_str', 'TEXT', 0, None, 0)]
# 字段名: id, 数据类型: TEXT
# 字段名: name, 数据类型: TEXT
# 字段名: dimension, 数据类型: INTEGER
# 字段名: database_id, 数据类型: TEXT
# 字段名: config_json_str, 数据类型: TEXT
# 字段名: schema_str, 数据类型: TEXT
# ----------------------------------------
# 表名: maintenance_log
# 字段: [(0, 'id', 'INT', 0, None, 1), (1, 'timestamp', 'INT', 1, None, 0), (2, 'operation', 'TEXT', 1, None, 0)]
# 字段名: id, 数据类型: INT
# 字段名: timestamp, 数据类型: INT
# 字段名: operation, 数据类型: TEXT
# ----------------------------------------
# 表名: segments
# 字段: [(0, 'id', 'TEXT', 0, None, 1), (1, 'type', 'TEXT', 1, None, 0), (2, 'scope', 'TEXT', 1, None, 0), (3, 'collection', 'TEXT', 1, None, 0)]
# 字段名: id, 数据类型: TEXT
# 字段名: type, 数据类型: TEXT
# 字段名: scope, 数据类型: TEXT
# 字段名: collection, 数据类型: TEXT
# ----------------------------------------
# 表名: embeddings
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'segment_id', 'TEXT', 1, None, 0), (2, 'embedding_id', 'TEXT', 1, None, 0), (3, 'seq_id', 'BLOB', 1, None, 0), (4, 'created_at', 'TIMESTAMP', 1, 'CURRENT_TIMESTAMP', 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: segment_id, 数据类型: TEXT
# 字段名: embedding_id, 数据类型: TEXT
# 字段名: seq_id, 数据类型: BLOB
# 字段名: created_at, 数据类型: TIMESTAMP
# ----------------------------------------
# 表名: embedding_metadata
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'key', 'TEXT', 1, None, 2), (2, 'string_value', 'TEXT', 0, None, 0), (3, 'int_value', 'INTEGER', 0, None, 0), (4, 'float_value', 'REAL', 0, None, 0), (5, 'bool_value', 'INTEGER', 0, None, 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: key, 数据类型: TEXT
# 字段名: string_value, 数据类型: TEXT
# 字段名: int_value, 数据类型: INTEGER
# 字段名: float_value, 数据类型: REAL
# 字段名: bool_value, 数据类型: INTEGER
# ----------------------------------------
# 表名: max_seq_id
# 字段: [(0, 'segment_id', 'TEXT', 0, None, 1), (1, 'seq_id', 'INTEGER', 0, None, 0)]
# 字段名: segment_id, 数据类型: TEXT
# 字段名: seq_id, 数据类型: INTEGER
# ----------------------------------------
# 表名: embedding_fulltext_search
# 字段: [(0, 'string_value', '', 0, None, 0)]
# 字段名: string_value, 数据类型:
# ----------------------------------------
# 表名: embedding_fulltext_search_data
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'block', 'BLOB', 0, None, 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: block, 数据类型: BLOB
# ----------------------------------------
# 表名: embedding_fulltext_search_idx
# 字段: [(0, 'segid', '', 1, None, 1), (1, 'term', '', 1, None, 2), (2, 'pgno', '', 0, None, 0)]
# 字段名: segid, 数据类型:
# 字段名: term, 数据类型:
# 字段名: pgno, 数据类型:
# ----------------------------------------
# 表名: embedding_fulltext_search_content
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'c0', '', 0, None, 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: c0, 数据类型:
# ----------------------------------------
# 表名: embedding_fulltext_search_docsize
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'sz', 'BLOB', 0, None, 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: sz, 数据类型: BLOB
# ----------------------------------------
# 表名: embedding_fulltext_search_config
# 字段: [(0, 'k', '', 1, None, 1), (1, 'v', '', 0, None, 0)]
# 字段名: k, 数据类型:
# 字段名: v, 数据类型:
# ----------------------------------------
# 表名: embeddings_queue
# 字段: [(0, 'seq_id', 'INTEGER', 0, None, 1), (1, 'created_at', 'TIMESTAMP', 1, 'CURRENT_TIMESTAMP', 0), (2, 'operation', 'INTEGER', 1, None, 0), (3, 'topic', 'TEXT', 1, None, 0), (4, 'id', 'TEXT', 1, None, 0), (5, 'vector', 'BLOB', 0, None, 0), (6, 'encoding', 'TEXT', 0, None, 0), (7, 'metadata', 'TEXT', 0, None, 0)]
# 字段名: seq_id, 数据类型: INTEGER
# 字段名: created_at, 数据类型: TIMESTAMP
# 字段名: operation, 数据类型: INTEGER
# 字段名: topic, 数据类型: TEXT
# 字段名: id, 数据类型: TEXT
# 字段名: vector, 数据类型: BLOB
# 字段名: encoding, 数据类型: TEXT
# 字段名: metadata, 数据类型: TEXT
# ----------------------------------------
# 表名: embeddings_queue_config
# 字段: [(0, 'id', 'INTEGER', 0, None, 1), (1, 'config_json_str', 'TEXT', 0, None, 0)]
# 字段名: id, 数据类型: INTEGER
# 字段名: config_json_str, 数据类型: TEXT
# ----------------------------------------
